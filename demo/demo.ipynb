# %%
"""
we need to perform addition operations on numbers
Example1 -
user: add 2 numbers, 4 and 5
assistant : Addition of 4 and 5 is 9

Example2 - 
user: add 4 numbers 3,4,5 & 78
assistant: to add four numbers, we take two numbers at a time, then add the third number to the result and then the forth and so on,
so here, we add 3 and 4, which results in 7, then add 5 to it, which results in 12, and then add 78 to it, which gives the final answer as 90
"""
